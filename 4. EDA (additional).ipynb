# %%
import cv2

import re

import matplotlib.pyplot as plt

import numpy as np

import pandas as pd

import re

import pymorphy2



import varname

import advertools as adv



import matplotlib.pyplot as plt #for visualization

import seaborn as sns #for visualization

import datetime

import ast 

import dostoevsky

import os

from sklearn.ensemble import GradientBoostingRegressor

from stop_words import get_stop_words

import string



# pd.set_option('display.max_rows', None)



pd.set_option('display.max_colwidth', None)

pd.set_option('display.max_columns', None)



from sklearn.ensemble import RandomForestRegressor

from sklearn.tree import DecisionTreeRegressor

from sklearn.metrics import mean_squared_error

from sklearn.model_selection import train_test_split

from sklearn import linear_model #линейные модели

from sklearn import metrics #метрики

from sklearn import preprocessing #предобработка

from sklearn.model_selection import KFold

from sklearn.model_selection import cross_val_score

from sklearn.linear_model import LinearRegression

from numpy import mean

from numpy import absolute

from numpy import sqrt

import pandas as pd

from sklearn.manifold import TSNE

import swifter

# Визуализация

import plotly.express as px # для визуализации данных

import matplotlib.pyplot as plt # для отображения рукописных цифр

from sklearn.preprocessing import MinMaxScaler

from sklearn.preprocessing import StandardScaler

from sklearn.preprocessing import RobustScaler

import math



from swifter import set_defaults

set_defaults(

    npartitions=None,

    dask_threshold=1,

    scheduler="processes",

    progress_bar=False,

    progress_bar_desc=None,

    allow_dask_on_strings=False,

    force_parallel=False,

)



from dostoevsky.tokenization import RegexTokenizer

from dostoevsky.models import FastTextSocialNetworkModel



from PIL import Image



import timeit

import datetime

import time



from pymystem3 import Mystem



import joblib
# Out:
# C:\Users\Arwielao\AppData\Roaming\Python\Python310\site-packages\numpy\_distributor_init.py:30: UserWarning: loaded more than 1 DLL from .libs:
# C:\Users\Arwielao\AppData\Roaming\Python\Python310\site-packages\numpy\.libs\libopenblas.EL2C6PLE4ZYW3ECEVIV3OXXGRN2NRFM2.gfortran-win_amd64.dll
# C:\Users\Arwielao\AppData\Roaming\Python\Python310\site-packages\numpy\.libs\libopenblas.FB5AE2TYXYH2IJRDKGDGQ3XBKLKTF43H.gfortran-win_amd64.dll
#   warnings.warn("loaded more than 1 DLL from .libs:"

# %%
grand_df_complex = pd.read_csv('grand_data_zero_3.csv')

grand_df = grand_df_complex.copy()

grand_df.rename(columns={"s_max.1": "v_max"}, inplace=True)

# %%
importance = pd.read_csv('importance.csv')

# %%
target = 'forwards_to_views'

# %%
plt.figure(figsize=(25,8))

sns.barplot(data=importance[:50], x='features', y='importance')

plt.xticks(rotation=90, size=16)

plt.yticks(size=16)
# Out:
# (array([0., 1., 2., 3., 4., 5., 6.]),
#  [Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, '')])
# C:\Users\Arwielao\AppData\Roaming\Python\Python310\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 128059 (\N{BEAR FACE}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\Arwielao\AppData\Roaming\Python\Python310\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 127757 (\N{EARTH GLOBE EUROPE-AFRICA}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
plt.figure(figsize=(25,8))

sns.scatterplot(data=grand_df, x='h', y=target)
# Out:
# <AxesSubplot:xlabel='h', ylabel='forwards_to_views'>

# %%
plt.figure(figsize=(25,8))

sns.scatterplot(data=grand_df, x='w', y=target)
# Out:
# <AxesSubplot:xlabel='w', ylabel='forwards_to_views'>

# %% [markdown]
# # Самые репостовые оказываются разрешения 1280 х 720

# %%
plt.figure(figsize=(25,8))

sns.scatterplot(data=grand_df, x='MessageEntityTextUrl', y=target)
# Out:
# <AxesSubplot:xlabel='MessageEntityTextUrl', ylabel='forwards_to_views'>

# %% [markdown]
# # Посты без ссылок лучше репостятся

# %%
plt.figure(figsize=(25,8))

sns.scatterplot(data=grand_df, x='MessageEntityBold', y=target)
# Out:
# <AxesSubplot:xlabel='MessageEntityBold', ylabel='forwards_to_views'>

# %% [markdown]
# # Посты со шрифтом небольшой толщиной или с ее отсутсвием лучше репостятся

# %%
importance[:30]
# Out:
#                 features  importance
# 0                      h    5.044021
# 1                      w    4.261866
# 2   MessageEntityTextUrl    3.790689
# 3      MessageEntityBold    3.518880
# 4            day_of_year    3.357995
# 5                 minute    2.959939
# 6   list_of_count_colors    2.414779
# 7               positive    2.340904
# 8                 second    2.239669
# 9          word_number_4    2.189590
# 10              negative    2.154013
# 11         word_number_2    1.932985
# 12                  skip    1.850047
# 13                  hour    1.805748
# 14              duration    1.800811
# 15      weight_to_height    1.783129
# 16               neutral    1.742538
# 17                speech    1.712102
# 18            blue-green    1.657100
# 19               🐻in_msg    1.462174
# 20         word_number_1    1.421729
# 21               🌍in_msg    1.293081
# 22                 green    1.232643
# 23                 r_std    1.220388
# ...

# %%
importance.loc[6,'features']
# Out:
# 'list_of_count_colors'

# %%
plt.figure(figsize=(25,8))

sns.scatterplot(data=grand_df, x='day_of_year', y=target)
# Out:
# <AxesSubplot:xlabel='day_of_year', ylabel='forwards_to_views'>

# %% [markdown]
# # Под Новый Год слегка больше репостов

# %%
plt.figure(figsize=(25,8))

sns.scatterplot(data=grand_df, x='minute', y=target)
# Out:
# <AxesSubplot:xlabel='minute', ylabel='forwards_to_views'>

# %%
plt.figure(figsize=(25,8))

sns.scatterplot(data=grand_df, x='list_of_count_colors', y=target)
# Out:
# <AxesSubplot:xlabel='list_of_count_colors', ylabel='forwards_to_views'>

# %% [markdown]
# # Видео не должно содержать много цветов, оптимально около 20-30 тыс.

# %%
importance.loc[6,'features']
# Out:
# 'list_of_count_colors'

# %%
plt.figure(figsize=(25,8))

sns.scatterplot(data=grand_df, x=importance.loc[7,'features'], y=target)
# Out:
# <AxesSubplot:xlabel='positive', ylabel='forwards_to_views'>

# %% [markdown]
# # Очевидно, чем меньше позитива, тем больше репостов (странно)

# %%
plt.figure(figsize=(25,8))

sns.scatterplot(data=grand_df, x=importance.loc[8,'features'], y=target)
# Out:
# <AxesSubplot:xlabel='second', ylabel='forwards_to_views'>

# %%
plt.figure(figsize=(25,8))

sns.scatterplot(data=grand_df, x=importance.loc[9,'features'], y=target)
# Out:
# <AxesSubplot:xlabel='word_number_4', ylabel='forwards_to_views'>

# %% [markdown]
# # Чем популярнее четвертое слово, тем выш репостовость

# %%
plt.figure(figsize=(25,8))

sns.scatterplot(data=grand_df, x=importance.loc[10,'features'], y=target)
# Out:
# <AxesSubplot:xlabel='negative', ylabel='forwards_to_views'>

# %% [markdown]
# # Чем меньше негатива, тем выше репостовость

# %%
plt.figure(figsize=(25,8))

sns.scatterplot(data=grand_df, x=importance.loc[11,'features'], y=target)
# Out:
# <AxesSubplot:xlabel='word_number_2', ylabel='forwards_to_views'>

# %% [markdown]
# # Чем популярнее слово второе, тем больше репостов

# %%
plt.figure(figsize=(25,8))

sns.scatterplot(data=grand_df, x=importance.loc[12,'features'], y=target)
# Out:
# <AxesSubplot:xlabel='skip', ylabel='forwards_to_views'>

# %% [markdown]
# # Чем меньше skip, тем больше репостов (не знаю отчего это зависит)

# %%
plt.figure(figsize=(25,8))

sns.scatterplot(data=grand_df, x=importance.loc[13,'features'], y=target)
# Out:
# <AxesSubplot:xlabel='hour', ylabel='forwards_to_views'>

# %%
plt.figure(figsize=(25,8))

sns.scatterplot(data=grand_df, x=importance.loc[15,'features'], y=target)
# Out:
# <AxesSubplot:xlabel='weight_to_height', ylabel='forwards_to_views'>

# %% [markdown]
# # Наиболее репостовые соотношения близки к 1.6 или золотому сечению

# %%
plt.figure(figsize=(25,8))

sns.scatterplot(data=grand_df, x=importance.loc[16,'features'], y=target)
# Out:
# <AxesSubplot:xlabel='neutral', ylabel='forwards_to_views'>

# %% [markdown]
# # Очень большой нейтрал или очень малый приводит к большим репостам

# %%
plt.figure(figsize=(25,8))

sns.scatterplot(data=grand_df, x=importance.loc[17,'features'], y=target)
# Out:
# <AxesSubplot:xlabel='speech', ylabel='forwards_to_views'>

# %% [markdown]
# # Speech должен быть как можно меньше

# %%
plt.figure(figsize=(25,8))

sns.scatterplot(data=grand_df, x=importance.loc[18,'features'], y=target)
# Out:
# <AxesSubplot:xlabel='blue-green', ylabel='forwards_to_views'>

# %%
plt.figure(figsize=(25,8))

sns.scatterplot(data=grand_df, x=importance.loc[19,'features'], y=target)
# Out:
# <AxesSubplot:xlabel='🐻in_msg', ylabel='forwards_to_views'>
# C:\Users\Arwielao\AppData\Roaming\Python\Python310\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 128059 (\N{BEAR FACE}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)

# %% [markdown]
# # Видимо случайность, но нет медведя больше репостов )

# %%
plt.figure(figsize=(25,8))

sns.scatterplot(data=grand_df, x=importance.loc[20,'features'], y=target)
# Out:
# <AxesSubplot:xlabel='word_number_1', ylabel='forwards_to_views'>

# %% [markdown]
# # Чем попоулярнее первое слово, тем выше репостовость

# %%
plt.figure(figsize=(25,8))

sns.scatterplot(data=grand_df, x=importance.loc[21,'features'], y=target)
# Out:
# <AxesSubplot:xlabel='🌍in_msg', ylabel='forwards_to_views'>
# C:\Users\Arwielao\AppData\Roaming\Python\Python310\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 127757 (\N{EARTH GLOBE EUROPE-AFRICA}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)

# %% [markdown]
# # С глобусом, как с Мишкой

# %%
plt.figure(figsize=(25,8))

sns.scatterplot(data=grand_df, x=importance.loc[22,'features'], y=target)
# Out:
# <AxesSubplot:xlabel='green', ylabel='forwards_to_views'>

# %%
plt.figure(figsize=(25,8))

sns.scatterplot(data=grand_df, x=importance.loc[23,'features'], y=target)
# Out:
# <AxesSubplot:xlabel='r_std', ylabel='forwards_to_views'>

# %% [markdown]
# # Красный канал должен назодиться на значениях около 60 для максимальной репостовости

# %%
plt.figure(figsize=(25,8))

sns.scatterplot(data=grand_df, x=importance.loc[25,'features'], y=target)
# Out:
# <AxesSubplot:xlabel='orange', ylabel='forwards_to_views'>

# %%
plt.figure(figsize=(25,8))

sns.scatterplot(data=grand_df, x=importance.loc[26,'features'], y=target)
# Out:
# <AxesSubplot:xlabel='word_number_3', ylabel='forwards_to_views'>

# %% [markdown]
# # С третьим словом аналогично с первым - четвертым

# %%
plt.figure(figsize=(25,8))

sns.scatterplot(data=grand_df, x=importance.loc[27,'features'], y=target)
# Out:
# <AxesSubplot:xlabel='s_median', ylabel='forwards_to_views'>

# %%
plt.figure(figsize=(25,8))

sns.scatterplot(data=grand_df, x=importance.loc[28,'features'], y=target)
# Out:
# <AxesSubplot:xlabel='word_number_5', ylabel='forwards_to_views'>

# %%
plt.figure(figsize=(25,8))

sns.scatterplot(data=grand_df, x=importance.loc[29,'features'], y=target)
# Out:
# <AxesSubplot:xlabel='blue', ylabel='forwards_to_views'>

# %% [markdown]
# # Если не учитывать выбросы, то чем меньше синего, тем лучше

# %%
plt.figure(figsize=(25,8))

sns.scatterplot(data=grand_df, x=importance.loc[30,'features'], y=target)
# Out:
# <AxesSubplot:xlabel='saturation_hsv_mean', ylabel='forwards_to_views'>

# %% [markdown]
# # Средняя saturation д.б. на уровне 50-60 ед. из 255

# %% [markdown]
# # В целом много важных признаков, свыше 100 - 200, что говорит о наличии некоторой закономерности в репостовости каждого сообщения

# %%
plt.figure(figsize=(25,8))

sns.histplot(data=grand_df,x=target)
# Out:
# <AxesSubplot:xlabel='forwards_to_views', ylabel='Count'>

# %% [markdown]
# # Много выбросов, начиная с 0.05

# %%
grand_df[target].min()
# Out:
# 4.5695485286053735e-05

# %%
grand_df[target].max()
# Out:
# 0.2222222222222222

# %% [markdown]
# # Таргет в широком диапазоне изменяется от 4.5e-5 до 0.22, из-за этого таргет пришлось логарифмировать

# %%
plt.figure(figsize=(25,8))

sns.histplot(data=grand_df,x='weight_to_height')
# Out:
# <AxesSubplot:xlabel='weight_to_height', ylabel='Count'>

# %%
importance[30:50]
# Out:
#                features  importance
# 30  saturation_hsv_mean    0.928678
# 31         day_of_month    0.928307
# 32               pink_1    0.895696
# 33               yellow    0.889130
# 34             h_median    0.885834
# 35                 grey    0.817087
# 36                s_std    0.794935
# 37                h_std    0.790944
# 38               pink_2    0.773526
# 39                white    0.761345
# 40                brown    0.744746
# 41                g_std    0.742295
# 42             v_median    0.739749
# 43               purple    0.734826
# 44               b_mean    0.717988
# 45                month    0.704039
# 46       value_hsv_mean    0.687117
# 47         hue_hsv_mean    0.683805
# 48        word_number_6    0.680094
# 49         light-purple    0.679449

# %%
plt.figure(figsize=(25,8))

sns.histplot(data=grand_df,x='day_of_year')
# Out:
# <AxesSubplot:xlabel='day_of_year', ylabel='Count'>

# %% [markdown]
# # Под новый год увеличивается количество сообщений

# %%
plt.figure(figsize=(25,8))

sns.histplot(data=grand_df,x='hue_hsv_mean')
# Out:
# <AxesSubplot:xlabel='hue_hsv_mean', ylabel='Count'>

# %%
plt.figure(figsize=(25,8))

sns.histplot(data=grand_df,x='light-purple')
# Out:
# <AxesSubplot:xlabel='light-purple', ylabel='Count'>

# %%
plt.figure(figsize=(25,8))

sns.histplot(data=grand_df,x='white')
# Out:
# <AxesSubplot:xlabel='white', ylabel='Count'>

# %%
plt.figure(figsize=(25,8))

sns.histplot(data=grand_df,x='grey')
# Out:
# <AxesSubplot:xlabel='grey', ylabel='Count'>

# %%
plt.figure(figsize=(25,8))

sns.histplot(data=grand_df,x='word_number_6')
# Out:
# <AxesSubplot:xlabel='word_number_6', ylabel='Count'>

# %% [markdown]
# # Кластеризация
